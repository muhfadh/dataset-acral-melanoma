# %% [markdown]
# ### Code untuk di Jupyter notebook

# %%
# %cd D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]
# Out:
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]

# %%
# %ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is BC6D-4CE5
#
#  Directory of D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]
#
# 13/12/2021  14:51    <DIR>          .
# 13/12/2021  14:51    <DIR>          ..
# 13/12/2021  14:50    <DIR>          testing
# 13/12/2021  14:50    <DIR>          training
#                0 File(s)              0 bytes
#                4 Dir(s)  962.147.590.144 bytes free

# %%
import os
# path di jupyter
base_dataset = 'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [80 20]/'

# %%
# inisialisasi direktori data train dan validasi beserta data per kategori
dir1 = [r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [80 20]/training/acral melanoma/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [80 20]/testing/acral melanoma/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [80 20]/training/benign nevi/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [80 20]/testing/benign nevi/']

# %% [markdown]
# # SVM Classifier

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size)
    img_arr = (np.array(nimg))
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
# %matplotlib inline
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten, Dropout 
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from PIL import Image

import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
import os

# %%
def get_imlist(path):
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]

# %%
from keras.models import Model
from keras.layers import Flatten, Dropout, Dense, Input, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate

class FeatureExtractor:
    def __init__(self):
        inputs = Input(shape=(224,224,3))
      
        conv1 = Conv2D(32, kernel_size=3, strides = 1, activation='relu')(inputs)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
        
        conv1 = Conv2D(64, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(128, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(256, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(512, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        flat = Flatten()(pool1)
        drop_out1 = Dropout(0.5)(flat)

        self.model = Model(inputs=inputs, outputs=drop_out1)
        

    def extract_features(self, img_path):
        im = Image.open(img_path)
        X = preprocess(im,(224,224))
        X = reshape([X])
        
        feat = self.model.predict(X)
        norm_feat = feat[0]/LA.norm(feat[0])
        return norm_feat

# %%
model = FeatureExtractor()

# %%
feats = []
names = []
dir_training = [dir1[0], dir1[2]]

for direktori in dir_training:
    img_list = get_imlist(direktori)
    for i, img_path in enumerate(img_list):
        norm_feat = model.extract_features(img_path)
        img_name = os.path.split(img_path)[1]
        feats.append(norm_feat)
        if 'AM' in img_name:
            names.append('acral melanoma')
        else:
            names.append('benign nevi')
        print("extracting feature from image No. %d , %d images in total" %((i+1), len(img_list)))

feats = np.array(feats)
names = np.array(names)
# Out:
# extracting feature from image No. 1 , 266 images in total
# extracting feature from image No. 2 , 266 images in total
# extracting feature from image No. 3 , 266 images in total
# extracting feature from image No. 4 , 266 images in total
# extracting feature from image No. 5 , 266 images in total
# extracting feature from image No. 6 , 266 images in total
# extracting feature from image No. 7 , 266 images in total
# extracting feature from image No. 8 , 266 images in total
# extracting feature from image No. 9 , 266 images in total
# extracting feature from image No. 10 , 266 images in total
# extracting feature from image No. 11 , 266 images in total
# extracting feature from image No. 12 , 266 images in total
# extracting feature from image No. 13 , 266 images in total
# extracting feature from image No. 14 , 266 images in total
# extracting feature from image No. 15 , 266 images in total
# extracting feature from image No. 16 , 266 images in total
# extracting feature from image No. 17 , 266 images in total
# extracting feature from image No. 18 , 266 images in total
# extracting feature from image No. 19 , 266 images in total
# extracting feature from image No. 20 , 266 images in total
# extracting feature from image No. 21 , 266 images in total
# extracting feature from image No. 22 , 266 images in total
# extracting feature from image No. 23 , 266 images in total
# extracting feature from image No. 24 , 266 images in total
# extracting feature from image No. 25 , 266 images in total
# extracting feature from image No. 26 , 266 images in total
# extracting feature from image No. 27 , 266 images in total
# extracting feature from image No. 28 , 266 images in total
# extracting feature from image No. 29 , 266 images in total
# extracting feature from image No. 30 , 266 images in total
# extracting feature from image No. 31 , 266 images in total
# extracting feature from image No. 32 , 266 images in total
# extracting feature from image No. 33 , 266 images in total
# extracting feature from image No. 34 , 266 images in total
# extracting feature from image No. 35 , 266 images in total
# extracting feature from image No. 36 , 266 images in total
# extracting feature from image No. 37 , 266 images in total
# extracting feature from image No. 38 , 266 images in total
# extracting feature from image No. 39 , 266 images in total
# extracting feature from image No. 40 , 266 images in total
# extracting feature from image No. 41 , 266 images in total
# extracting feature from image No. 42 , 266 images in total
# extracting feature from image No. 43 , 266 images in total
# extracting feature from image No. 44 , 266 images in total
# extracting feature from image No. 45 , 266 images in total
# extracting feature from image No. 46 , 266 images in total
# extracting feature from image No. 47 , 266 images in total
# extracting feature from image No. 48 , 266 images in total
# extracting feature from image No. 49 , 266 images in total
# extracting feature from image No. 50 , 266 images in total
# extracting feature from image No. 51 , 266 images in total
# extracting feature from image No. 52 , 266 images in total
# extracting feature from image No. 53 , 266 images in total
# extracting feature from image No. 54 , 266 images in total
# extracting feature from image No. 55 , 266 images in total
# extracting feature from image No. 56 , 266 images in total
# extracting feature from image No. 57 , 266 images in total
# extracting feature from image No. 58 , 266 images in total
# extracting feature from image No. 59 , 266 images in total
# extracting feature from image No. 60 , 266 images in total
# extracting feature from image No. 61 , 266 images in total
# extracting feature from image No. 62 , 266 images in total
# extracting feature from image No. 63 , 266 images in total
# extracting feature from image No. 64 , 266 images in total
# extracting feature from image No. 65 , 266 images in total
# extracting feature from image No. 66 , 266 images in total
# extracting feature from image No. 67 , 266 images in total
# extracting feature from image No. 68 , 266 images in total
# extracting feature from image No. 69 , 266 images in total
# extracting feature from image No. 70 , 266 images in total
# extracting feature from image No. 71 , 266 images in total
# extracting feature from image No. 72 , 266 images in total
# extracting feature from image No. 73 , 266 images in total
# extracting feature from image No. 74 , 266 images in total
# extracting feature from image No. 75 , 266 images in total
# extracting feature from image No. 76 , 266 images in total
# extracting feature from image No. 77 , 266 images in total
# extracting feature from image No. 78 , 266 images in total
# extracting feature from image No. 79 , 266 images in total
# extracting feature from image No. 80 , 266 images in total
# extracting feature from image No. 81 , 266 images in total
# extracting feature from image No. 82 , 266 images in total
# extracting feature from image No. 83 , 266 images in total
# extracting feature from image No. 84 , 266 images in total
# extracting feature from image No. 85 , 266 images in total
# extracting feature from image No. 86 , 266 images in total
# extracting feature from image No. 87 , 266 images in total
# extracting feature from image No. 88 , 266 images in total
# extracting feature from image No. 89 , 266 images in total
# extracting feature from image No. 90 , 266 images in total
# extracting feature from image No. 91 , 266 images in total
# extracting feature from image No. 92 , 266 images in total
# extracting feature from image No. 93 , 266 images in total
# extracting feature from image No. 94 , 266 images in total
# extracting feature from image No. 95 , 266 images in total
# extracting feature from image No. 96 , 266 images in total
# extracting feature from image No. 97 , 266 images in total
# extracting feature from image No. 98 , 266 images in total
# extracting feature from image No. 99 , 266 images in total
# extracting feature from image No. 100 , 266 images in total
# extracting feature from image No. 101 , 266 images in total
# extracting feature from image No. 102 , 266 images in total
# extracting feature from image No. 103 , 266 images in total
# extracting feature from image No. 104 , 266 images in total
# extracting feature from image No. 105 , 266 images in total
# extracting feature from image No. 106 , 266 images in total
# extracting feature from image No. 107 , 266 images in total
# extracting feature from image No. 108 , 266 images in total
# extracting feature from image No. 109 , 266 images in total
# extracting feature from image No. 110 , 266 images in total
# extracting feature from image No. 111 , 266 images in total
# extracting feature from image No. 112 , 266 images in total
# extracting feature from image No. 113 , 266 images in total
# extracting feature from image No. 114 , 266 images in total
# extracting feature from image No. 115 , 266 images in total
# extracting feature from image No. 116 , 266 images in total
# extracting feature from image No. 117 , 266 images in total
# extracting feature from image No. 118 , 266 images in total
# extracting feature from image No. 119 , 266 images in total
# extracting feature from image No. 120 , 266 images in total
# extracting feature from image No. 121 , 266 images in total
# extracting feature from image No. 122 , 266 images in total
# extracting feature from image No. 123 , 266 images in total
# extracting feature from image No. 124 , 266 images in total
# extracting feature from image No. 125 , 266 images in total
# extracting feature from image No. 126 , 266 images in total
# extracting feature from image No. 127 , 266 images in total
# extracting feature from image No. 128 , 266 images in total
# extracting feature from image No. 129 , 266 images in total
# extracting feature from image No. 130 , 266 images in total
# extracting feature from image No. 131 , 266 images in total
# extracting feature from image No. 132 , 266 images in total
# extracting feature from image No. 133 , 266 images in total
# extracting feature from image No. 134 , 266 images in total
# extracting feature from image No. 135 , 266 images in total
# extracting feature from image No. 136 , 266 images in total
# extracting feature from image No. 137 , 266 images in total
# extracting feature from image No. 138 , 266 images in total
# extracting feature from image No. 139 , 266 images in total
# extracting feature from image No. 140 , 266 images in total
# extracting feature from image No. 141 , 266 images in total
# extracting feature from image No. 142 , 266 images in total
# extracting feature from image No. 143 , 266 images in total
# extracting feature from image No. 144 , 266 images in total
# extracting feature from image No. 145 , 266 images in total
# extracting feature from image No. 146 , 266 images in total
# extracting feature from image No. 147 , 266 images in total
# extracting feature from image No. 148 , 266 images in total
# extracting feature from image No. 149 , 266 images in total
# extracting feature from image No. 150 , 266 images in total
# extracting feature from image No. 151 , 266 images in total
# extracting feature from image No. 152 , 266 images in total
# extracting feature from image No. 153 , 266 images in total
# extracting feature from image No. 154 , 266 images in total
# extracting feature from image No. 155 , 266 images in total
# extracting feature from image No. 156 , 266 images in total
# extracting feature from image No. 157 , 266 images in total
# extracting feature from image No. 158 , 266 images in total
# extracting feature from image No. 159 , 266 images in total
# extracting feature from image No. 160 , 266 images in total
# extracting feature from image No. 161 , 266 images in total
# extracting feature from image No. 162 , 266 images in total
# extracting feature from image No. 163 , 266 images in total
# extracting feature from image No. 164 , 266 images in total
# extracting feature from image No. 165 , 266 images in total
# extracting feature from image No. 166 , 266 images in total
# extracting feature from image No. 167 , 266 images in total
# extracting feature from image No. 168 , 266 images in total
# extracting feature from image No. 169 , 266 images in total
# extracting feature from image No. 170 , 266 images in total
# extracting feature from image No. 171 , 266 images in total
# extracting feature from image No. 172 , 266 images in total
# extracting feature from image No. 173 , 266 images in total
# extracting feature from image No. 174 , 266 images in total
# extracting feature from image No. 175 , 266 images in total
# extracting feature from image No. 176 , 266 images in total
# extracting feature from image No. 177 , 266 images in total
# extracting feature from image No. 178 , 266 images in total
# extracting feature from image No. 179 , 266 images in total
# extracting feature from image No. 180 , 266 images in total
# extracting feature from image No. 181 , 266 images in total
# extracting feature from image No. 182 , 266 images in total
# extracting feature from image No. 183 , 266 images in total
# extracting feature from image No. 184 , 266 images in total
# extracting feature from image No. 185 , 266 images in total
# extracting feature from image No. 186 , 266 images in total
# extracting feature from image No. 187 , 266 images in total
# extracting feature from image No. 188 , 266 images in total
# extracting feature from image No. 189 , 266 images in total
# extracting feature from image No. 190 , 266 images in total
# extracting feature from image No. 191 , 266 images in total
# extracting feature from image No. 192 , 266 images in total
# extracting feature from image No. 193 , 266 images in total
# extracting feature from image No. 194 , 266 images in total
# extracting feature from image No. 195 , 266 images in total
# extracting feature from image No. 196 , 266 images in total
# extracting feature from image No. 197 , 266 images in total
# extracting feature from image No. 198 , 266 images in total
# extracting feature from image No. 199 , 266 images in total
# extracting feature from image No. 200 , 266 images in total
# extracting feature from image No. 201 , 266 images in total
# extracting feature from image No. 202 , 266 images in total
# extracting feature from image No. 203 , 266 images in total
# extracting feature from image No. 204 , 266 images in total
# extracting feature from image No. 205 , 266 images in total
# extracting feature from image No. 206 , 266 images in total
# extracting feature from image No. 207 , 266 images in total
# extracting feature from image No. 208 , 266 images in total
# extracting feature from image No. 209 , 266 images in total
# extracting feature from image No. 210 , 266 images in total
# extracting feature from image No. 211 , 266 images in total
# extracting feature from image No. 212 , 266 images in total
# extracting feature from image No. 213 , 266 images in total
# extracting feature from image No. 214 , 266 images in total
# extracting feature from image No. 215 , 266 images in total
# extracting feature from image No. 216 , 266 images in total
# extracting feature from image No. 217 , 266 images in total
# extracting feature from image No. 218 , 266 images in total
# extracting feature from image No. 219 , 266 images in total
# extracting feature from image No. 220 , 266 images in total
# extracting feature from image No. 221 , 266 images in total
# extracting feature from image No. 222 , 266 images in total
# extracting feature from image No. 223 , 266 images in total
# extracting feature from image No. 224 , 266 images in total
# extracting feature from image No. 225 , 266 images in total
# extracting feature from image No. 226 , 266 images in total
# extracting feature from image No. 227 , 266 images in total
# extracting feature from image No. 228 , 266 images in total
# extracting feature from image No. 229 , 266 images in total
# extracting feature from image No. 230 , 266 images in total
# extracting feature from image No. 231 , 266 images in total
# extracting feature from image No. 232 , 266 images in total
# extracting feature from image No. 233 , 266 images in total
# extracting feature from image No. 234 , 266 images in total
# extracting feature from image No. 235 , 266 images in total
# extracting feature from image No. 236 , 266 images in total
# extracting feature from image No. 237 , 266 images in total
# extracting feature from image No. 238 , 266 images in total
# extracting feature from image No. 239 , 266 images in total
# extracting feature from image No. 240 , 266 images in total
# extracting feature from image No. 241 , 266 images in total
# extracting feature from image No. 242 , 266 images in total
# extracting feature from image No. 243 , 266 images in total
# extracting feature from image No. 244 , 266 images in total
# extracting feature from image No. 245 , 266 images in total
# extracting feature from image No. 246 , 266 images in total
# extracting feature from image No. 247 , 266 images in total
# extracting feature from image No. 248 , 266 images in total
# extracting feature from image No. 249 , 266 images in total
# extracting feature from image No. 250 , 266 images in total
# extracting feature from image No. 251 , 266 images in total
# extracting feature from image No. 252 , 266 images in total
# extracting feature from image No. 253 , 266 images in total
# extracting feature from image No. 254 , 266 images in total
# extracting feature from image No. 255 , 266 images in total
# extracting feature from image No. 256 , 266 images in total
# extracting feature from image No. 257 , 266 images in total
# extracting feature from image No. 258 , 266 images in total
# extracting feature from image No. 259 , 266 images in total
# extracting feature from image No. 260 , 266 images in total
# extracting feature from image No. 261 , 266 images in total
# extracting feature from image No. 262 , 266 images in total
# extracting feature from image No. 263 , 266 images in total
# extracting feature from image No. 264 , 266 images in total
# extracting feature from image No. 265 , 266 images in total
# extracting feature from image No. 266 , 266 images in total
# extracting feature from image No. 1 , 218 images in total
# extracting feature from image No. 2 , 218 images in total
# extracting feature from image No. 3 , 218 images in total
# extracting feature from image No. 4 , 218 images in total
# extracting feature from image No. 5 , 218 images in total
# extracting feature from image No. 6 , 218 images in total
# extracting feature from image No. 7 , 218 images in total
# extracting feature from image No. 8 , 218 images in total
# extracting feature from image No. 9 , 218 images in total
# extracting feature from image No. 10 , 218 images in total
# extracting feature from image No. 11 , 218 images in total
# extracting feature from image No. 12 , 218 images in total
# extracting feature from image No. 13 , 218 images in total
# extracting feature from image No. 14 , 218 images in total
# extracting feature from image No. 15 , 218 images in total
# extracting feature from image No. 16 , 218 images in total
# extracting feature from image No. 17 , 218 images in total
# extracting feature from image No. 18 , 218 images in total
# extracting feature from image No. 19 , 218 images in total
# extracting feature from image No. 20 , 218 images in total
# extracting feature from image No. 21 , 218 images in total
# extracting feature from image No. 22 , 218 images in total
# extracting feature from image No. 23 , 218 images in total
# extracting feature from image No. 24 , 218 images in total
# extracting feature from image No. 25 , 218 images in total
# extracting feature from image No. 26 , 218 images in total
# extracting feature from image No. 27 , 218 images in total
# extracting feature from image No. 28 , 218 images in total
# extracting feature from image No. 29 , 218 images in total
# extracting feature from image No. 30 , 218 images in total
# extracting feature from image No. 31 , 218 images in total
# extracting feature from image No. 32 , 218 images in total
# extracting feature from image No. 33 , 218 images in total
# extracting feature from image No. 34 , 218 images in total
# extracting feature from image No. 35 , 218 images in total
# extracting feature from image No. 36 , 218 images in total
# extracting feature from image No. 37 , 218 images in total
# extracting feature from image No. 38 , 218 images in total
# extracting feature from image No. 39 , 218 images in total
# extracting feature from image No. 40 , 218 images in total
# extracting feature from image No. 41 , 218 images in total
# extracting feature from image No. 42 , 218 images in total
# extracting feature from image No. 43 , 218 images in total
# extracting feature from image No. 44 , 218 images in total
# extracting feature from image No. 45 , 218 images in total
# extracting feature from image No. 46 , 218 images in total
# extracting feature from image No. 47 , 218 images in total
# extracting feature from image No. 48 , 218 images in total
# extracting feature from image No. 49 , 218 images in total
# extracting feature from image No. 50 , 218 images in total
# extracting feature from image No. 51 , 218 images in total
# extracting feature from image No. 52 , 218 images in total
# extracting feature from image No. 53 , 218 images in total
# extracting feature from image No. 54 , 218 images in total
# extracting feature from image No. 55 , 218 images in total
# extracting feature from image No. 56 , 218 images in total
# extracting feature from image No. 57 , 218 images in total
# extracting feature from image No. 58 , 218 images in total
# extracting feature from image No. 59 , 218 images in total
# extracting feature from image No. 60 , 218 images in total
# extracting feature from image No. 61 , 218 images in total
# extracting feature from image No. 62 , 218 images in total
# extracting feature from image No. 63 , 218 images in total
# extracting feature from image No. 64 , 218 images in total
# extracting feature from image No. 65 , 218 images in total
# extracting feature from image No. 66 , 218 images in total
# extracting feature from image No. 67 , 218 images in total
# extracting feature from image No. 68 , 218 images in total
# extracting feature from image No. 69 , 218 images in total
# extracting feature from image No. 70 , 218 images in total
# extracting feature from image No. 71 , 218 images in total
# extracting feature from image No. 72 , 218 images in total
# extracting feature from image No. 73 , 218 images in total
# extracting feature from image No. 74 , 218 images in total
# extracting feature from image No. 75 , 218 images in total
# extracting feature from image No. 76 , 218 images in total
# extracting feature from image No. 77 , 218 images in total
# extracting feature from image No. 78 , 218 images in total
# extracting feature from image No. 79 , 218 images in total
# extracting feature from image No. 80 , 218 images in total
# extracting feature from image No. 81 , 218 images in total
# extracting feature from image No. 82 , 218 images in total
# extracting feature from image No. 83 , 218 images in total
# extracting feature from image No. 84 , 218 images in total
# extracting feature from image No. 85 , 218 images in total
# extracting feature from image No. 86 , 218 images in total
# extracting feature from image No. 87 , 218 images in total
# extracting feature from image No. 88 , 218 images in total
# extracting feature from image No. 89 , 218 images in total
# extracting feature from image No. 90 , 218 images in total
# extracting feature from image No. 91 , 218 images in total
# extracting feature from image No. 92 , 218 images in total
# extracting feature from image No. 93 , 218 images in total
# extracting feature from image No. 94 , 218 images in total
# extracting feature from image No. 95 , 218 images in total
# extracting feature from image No. 96 , 218 images in total
# extracting feature from image No. 97 , 218 images in total
# extracting feature from image No. 98 , 218 images in total
# extracting feature from image No. 99 , 218 images in total
# extracting feature from image No. 100 , 218 images in total
# extracting feature from image No. 101 , 218 images in total
# extracting feature from image No. 102 , 218 images in total
# extracting feature from image No. 103 , 218 images in total
# extracting feature from image No. 104 , 218 images in total
# extracting feature from image No. 105 , 218 images in total
# extracting feature from image No. 106 , 218 images in total
# extracting feature from image No. 107 , 218 images in total
# extracting feature from image No. 108 , 218 images in total
# extracting feature from image No. 109 , 218 images in total
# extracting feature from image No. 110 , 218 images in total
# extracting feature from image No. 111 , 218 images in total
# extracting feature from image No. 112 , 218 images in total
# extracting feature from image No. 113 , 218 images in total
# extracting feature from image No. 114 , 218 images in total
# extracting feature from image No. 115 , 218 images in total
# extracting feature from image No. 116 , 218 images in total
# extracting feature from image No. 117 , 218 images in total
# extracting feature from image No. 118 , 218 images in total
# extracting feature from image No. 119 , 218 images in total
# extracting feature from image No. 120 , 218 images in total
# extracting feature from image No. 121 , 218 images in total
# extracting feature from image No. 122 , 218 images in total
# extracting feature from image No. 123 , 218 images in total
# extracting feature from image No. 124 , 218 images in total
# extracting feature from image No. 125 , 218 images in total
# extracting feature from image No. 126 , 218 images in total
# extracting feature from image No. 127 , 218 images in total
# extracting feature from image No. 128 , 218 images in total
# extracting feature from image No. 129 , 218 images in total
# extracting feature from image No. 130 , 218 images in total
# extracting feature from image No. 131 , 218 images in total
# extracting feature from image No. 132 , 218 images in total
# extracting feature from image No. 133 , 218 images in total
# extracting feature from image No. 134 , 218 images in total
# extracting feature from image No. 135 , 218 images in total
# extracting feature from image No. 136 , 218 images in total
# extracting feature from image No. 137 , 218 images in total
# extracting feature from image No. 138 , 218 images in total
# extracting feature from image No. 139 , 218 images in total
# extracting feature from image No. 140 , 218 images in total
# extracting feature from image No. 141 , 218 images in total
# extracting feature from image No. 142 , 218 images in total
# extracting feature from image No. 143 , 218 images in total
# extracting feature from image No. 144 , 218 images in total
# extracting feature from image No. 145 , 218 images in total
# extracting feature from image No. 146 , 218 images in total
# extracting feature from image No. 147 , 218 images in total
# extracting feature from image No. 148 , 218 images in total
# extracting feature from image No. 149 , 218 images in total
# extracting feature from image No. 150 , 218 images in total
# extracting feature from image No. 151 , 218 images in total
# extracting feature from image No. 152 , 218 images in total
# extracting feature from image No. 153 , 218 images in total
# extracting feature from image No. 154 , 218 images in total
# extracting feature from image No. 155 , 218 images in total
# extracting feature from image No. 156 , 218 images in total
# extracting feature from image No. 157 , 218 images in total
# extracting feature from image No. 158 , 218 images in total
# extracting feature from image No. 159 , 218 images in total
# extracting feature from image No. 160 , 218 images in total
# extracting feature from image No. 161 , 218 images in total
# extracting feature from image No. 162 , 218 images in total
# extracting feature from image No. 163 , 218 images in total
# extracting feature from image No. 164 , 218 images in total
# extracting feature from image No. 165 , 218 images in total
# extracting feature from image No. 166 , 218 images in total
# extracting feature from image No. 167 , 218 images in total
# extracting feature from image No. 168 , 218 images in total
# extracting feature from image No. 169 , 218 images in total
# extracting feature from image No. 170 , 218 images in total
# extracting feature from image No. 171 , 218 images in total
# extracting feature from image No. 172 , 218 images in total
# extracting feature from image No. 173 , 218 images in total
# extracting feature from image No. 174 , 218 images in total
# extracting feature from image No. 175 , 218 images in total
# extracting feature from image No. 176 , 218 images in total
# extracting feature from image No. 177 , 218 images in total
# extracting feature from image No. 178 , 218 images in total
# extracting feature from image No. 179 , 218 images in total
# extracting feature from image No. 180 , 218 images in total
# extracting feature from image No. 181 , 218 images in total
# extracting feature from image No. 182 , 218 images in total
# extracting feature from image No. 183 , 218 images in total
# extracting feature from image No. 184 , 218 images in total
# extracting feature from image No. 185 , 218 images in total
# extracting feature from image No. 186 , 218 images in total
# extracting feature from image No. 187 , 218 images in total
# extracting feature from image No. 188 , 218 images in total
# extracting feature from image No. 189 , 218 images in total
# extracting feature from image No. 190 , 218 images in total
# extracting feature from image No. 191 , 218 images in total
# extracting feature from image No. 192 , 218 images in total
# extracting feature from image No. 193 , 218 images in total
# extracting feature from image No. 194 , 218 images in total
# extracting feature from image No. 195 , 218 images in total
# extracting feature from image No. 196 , 218 images in total
# extracting feature from image No. 197 , 218 images in total
# extracting feature from image No. 198 , 218 images in total
# extracting feature from image No. 199 , 218 images in total
# extracting feature from image No. 200 , 218 images in total
# extracting feature from image No. 201 , 218 images in total
# extracting feature from image No. 202 , 218 images in total
# extracting feature from image No. 203 , 218 images in total
# extracting feature from image No. 204 , 218 images in total
# extracting feature from image No. 205 , 218 images in total
# extracting feature from image No. 206 , 218 images in total
# extracting feature from image No. 207 , 218 images in total
# extracting feature from image No. 208 , 218 images in total
# extracting feature from image No. 209 , 218 images in total
# extracting feature from image No. 210 , 218 images in total
# extracting feature from image No. 211 , 218 images in total
# extracting feature from image No. 212 , 218 images in total
# extracting feature from image No. 213 , 218 images in total
# extracting feature from image No. 214 , 218 images in total
# extracting feature from image No. 215 , 218 images in total
# extracting feature from image No. 216 , 218 images in total
# extracting feature from image No. 217 , 218 images in total
# extracting feature from image No. 218 , 218 images in total

# %%
feats_test = []
names_test = []
dir_test = [dir1[1], dir1[3]]
for direktori in dir_test:
    img_list = get_imlist(direktori)
    for i, img_path in enumerate(img_list):
        norm_feat = model.extract_features(img_path)
        img_name = os.path.split(img_path)[1]
        feats_test.append(norm_feat)
        if 'AM' in img_name:
            names_test.append('acral melanoma')
        else:
            names_test.append('benign nevi')
        print("extracting feature from image No. %d , %d images in total" %((i+1), len(img_list)))

feats_test = np.array(feats_test)
names_test = np.array(names_test)
# Out:
# extracting feature from image No. 1 , 64 images in total
# extracting feature from image No. 2 , 64 images in total
# extracting feature from image No. 3 , 64 images in total
# extracting feature from image No. 4 , 64 images in total
# extracting feature from image No. 5 , 64 images in total
# extracting feature from image No. 6 , 64 images in total
# extracting feature from image No. 7 , 64 images in total
# extracting feature from image No. 8 , 64 images in total
# extracting feature from image No. 9 , 64 images in total
# extracting feature from image No. 10 , 64 images in total
# extracting feature from image No. 11 , 64 images in total
# extracting feature from image No. 12 , 64 images in total
# extracting feature from image No. 13 , 64 images in total
# extracting feature from image No. 14 , 64 images in total
# extracting feature from image No. 15 , 64 images in total
# extracting feature from image No. 16 , 64 images in total
# extracting feature from image No. 17 , 64 images in total
# extracting feature from image No. 18 , 64 images in total
# extracting feature from image No. 19 , 64 images in total
# extracting feature from image No. 20 , 64 images in total
# extracting feature from image No. 21 , 64 images in total
# extracting feature from image No. 22 , 64 images in total
# extracting feature from image No. 23 , 64 images in total
# extracting feature from image No. 24 , 64 images in total
# extracting feature from image No. 25 , 64 images in total
# extracting feature from image No. 26 , 64 images in total
# extracting feature from image No. 27 , 64 images in total
# extracting feature from image No. 28 , 64 images in total
# extracting feature from image No. 29 , 64 images in total
# extracting feature from image No. 30 , 64 images in total
# extracting feature from image No. 31 , 64 images in total
# extracting feature from image No. 32 , 64 images in total
# extracting feature from image No. 33 , 64 images in total
# extracting feature from image No. 34 , 64 images in total
# extracting feature from image No. 35 , 64 images in total
# extracting feature from image No. 36 , 64 images in total
# extracting feature from image No. 37 , 64 images in total
# extracting feature from image No. 38 , 64 images in total
# extracting feature from image No. 39 , 64 images in total
# extracting feature from image No. 40 , 64 images in total
# extracting feature from image No. 41 , 64 images in total
# extracting feature from image No. 42 , 64 images in total
# extracting feature from image No. 43 , 64 images in total
# extracting feature from image No. 44 , 64 images in total
# extracting feature from image No. 45 , 64 images in total
# extracting feature from image No. 46 , 64 images in total
# extracting feature from image No. 47 , 64 images in total
# extracting feature from image No. 48 , 64 images in total
# extracting feature from image No. 49 , 64 images in total
# extracting feature from image No. 50 , 64 images in total
# extracting feature from image No. 51 , 64 images in total
# extracting feature from image No. 52 , 64 images in total
# extracting feature from image No. 53 , 64 images in total
# extracting feature from image No. 54 , 64 images in total
# extracting feature from image No. 55 , 64 images in total
# extracting feature from image No. 56 , 64 images in total
# extracting feature from image No. 57 , 64 images in total
# extracting feature from image No. 58 , 64 images in total
# extracting feature from image No. 59 , 64 images in total
# extracting feature from image No. 60 , 64 images in total
# extracting feature from image No. 61 , 64 images in total
# extracting feature from image No. 62 , 64 images in total
# extracting feature from image No. 63 , 64 images in total
# extracting feature from image No. 64 , 64 images in total
# extracting feature from image No. 1 , 52 images in total
# extracting feature from image No. 2 , 52 images in total
# extracting feature from image No. 3 , 52 images in total
# extracting feature from image No. 4 , 52 images in total
# extracting feature from image No. 5 , 52 images in total
# extracting feature from image No. 6 , 52 images in total
# extracting feature from image No. 7 , 52 images in total
# extracting feature from image No. 8 , 52 images in total
# extracting feature from image No. 9 , 52 images in total
# extracting feature from image No. 10 , 52 images in total
# extracting feature from image No. 11 , 52 images in total
# extracting feature from image No. 12 , 52 images in total
# extracting feature from image No. 13 , 52 images in total
# extracting feature from image No. 14 , 52 images in total
# extracting feature from image No. 15 , 52 images in total
# extracting feature from image No. 16 , 52 images in total
# extracting feature from image No. 17 , 52 images in total
# extracting feature from image No. 18 , 52 images in total
# extracting feature from image No. 19 , 52 images in total
# extracting feature from image No. 20 , 52 images in total
# extracting feature from image No. 21 , 52 images in total
# extracting feature from image No. 22 , 52 images in total
# extracting feature from image No. 23 , 52 images in total
# extracting feature from image No. 24 , 52 images in total
# extracting feature from image No. 25 , 52 images in total
# extracting feature from image No. 26 , 52 images in total
# extracting feature from image No. 27 , 52 images in total
# extracting feature from image No. 28 , 52 images in total
# extracting feature from image No. 29 , 52 images in total
# extracting feature from image No. 30 , 52 images in total
# extracting feature from image No. 31 , 52 images in total
# extracting feature from image No. 32 , 52 images in total
# extracting feature from image No. 33 , 52 images in total
# extracting feature from image No. 34 , 52 images in total
# extracting feature from image No. 35 , 52 images in total
# extracting feature from image No. 36 , 52 images in total
# extracting feature from image No. 37 , 52 images in total
# extracting feature from image No. 38 , 52 images in total
# extracting feature from image No. 39 , 52 images in total
# extracting feature from image No. 40 , 52 images in total
# extracting feature from image No. 41 , 52 images in total
# extracting feature from image No. 42 , 52 images in total
# extracting feature from image No. 43 , 52 images in total
# extracting feature from image No. 44 , 52 images in total
# extracting feature from image No. 45 , 52 images in total
# extracting feature from image No. 46 , 52 images in total
# extracting feature from image No. 47 , 52 images in total
# extracting feature from image No. 48 , 52 images in total
# extracting feature from image No. 49 , 52 images in total
# extracting feature from image No. 50 , 52 images in total
# extracting feature from image No. 51 , 52 images in total
# extracting feature from image No. 52 , 52 images in total

# %%
from sklearn.preprocessing import LabelEncoder
x_train = feats
x_test= feats_test

lb = LabelEncoder()
y_train = lb.fit_transform(names)
y_test = lb.fit_transform(names_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'], 
              'C':[0.1,1, 10, 100,],
              'gamma':[1e-1,1e-2,1e-3, 1e-4]}
clf = GridSearchCV(SVC(), parameters)
clf.fit(x_train, y_train)

svmclf = clf.best_estimator_
#svmclf = SVC(C=100, gamma=0.1, kernel='linear', probability = True)
modelsvm = svmclf.fit(x_train, y_train)

# %%
svmclf
# Out:
# SVC(C=100, gamma=0.1, kernel='linear')

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
y_testSVM = modelsvm.predict(x_test)

labels = (y_testSVM > 0.5).astype(int)
target_names = ['acral melanoma', 'benign nevi']
print(classification_report(y_test, labels, target_names=target_names))

print('Confusion Matrix')
print(confusion_matrix(y_test, labels))
print('acc score : ', modelsvm.score(x_test,y_test))
# Out:
#                 precision    recall  f1-score   support
#
# acral melanoma       0.89      0.77      0.82        64
#    benign nevi       0.75      0.88      0.81        52
#
#       accuracy                           0.82       116
#      macro avg       0.82      0.83      0.82       116
#   weighted avg       0.83      0.82      0.82       116
#
# Confusion Matrix
# [[49 15]
#  [ 6 46]]
# acc score :  0.8189655172413793

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(modelsvm, x_test, y_test)  
plt.savefig('D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 2 - [80 20]/cm-skenario-2.svg')
plt.show()
# Out:
# C:\Users\Fadhlan\Anaconda3\envs\tf2.6\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
import h5py
h5f = h5py.File('D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [90 10]/model/model-skenario-2.h5', 'w')
h5f.create_dataset('train_features', data=x_train)
h5f.create_dataset('train_labels', data=y_train)
h5f.create_dataset('test_features', data=x_test)
h5f.create_dataset('test_labels', data=y_test)
h5f.close()

# %%
svmclf.get_params()
# Out:
# {'C': 100,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 0.1,
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
nrows = 4
ncols = 5
input_size = (224, 224)
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 5, nrows * 5)

pic_index += 20
melanoma_pix = [os.path.join(dir1[1], fname) for fname in os.listdir(dir1[1])[:10]]
benign_pix = [os.path.join(dir1[3], fname) for fname in os.listdir(dir1[3])[:10]]

for i, img_path in enumerate(melanoma_pix+benign_pix):
  # Set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows, ncols, i+1)
    categories = ['acral melanoma', 'benign nevi']
    im = Image.open(img_path)
    norm_feat = model.extract_features(img_path)
    norm_feat = np.array(norm_feat)
    norm_feat = norm_feat.reshape(1, len(norm_feat))
    start = time.time()
    y = svmclf.predict(norm_feat)
    waktu = time.time() - start

    if categories[int(np.round(y, 0))] == 'benign nevi':
        plt.title(categories[int(np.round(y, 0))] + ' pred: '+ str(int(np.round(y, 0))))
        plt.xlabel(' waktu: ' + str(waktu))
    else:
        plt.title(categories[int(np.round(y, 0))] + ' pred: '+ str(int(np.round(y, 0))))
        plt.xlabel(' waktu: ' + str(waktu))
    #sp.axis('Off') # Don't show axes (or gridlines)

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
from sklearn.metrics import  precision_recall_curve, auc, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
fpr, tpr, _ = roc_curve(y_test, labels)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='#ffba93',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='#7579e7', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Skenario 2')
plt.legend(loc="lower right")
plt.savefig('D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 2 - [80 20]/roc-curve-skenario-2.svg')
plt.show()

# %%
from pathlib import Path

input_path = [dir1[0], dir1[2]]
output_path = 'D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 2 - [80 20]' 

for path in input_path: 
    for img_path in sorted(Path(path).glob('*.jpg')):
        print(img_path)

        feature = model.extract_features(img_path)

        feature_path = Path(output_path) / (img_path.stem + ".npy")
        print(feature_path)

        np.save(feature_path, feature)
# Out:
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (1).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (1).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (101).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (101).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (102).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (102).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (103).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (103).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (106).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (106).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (108).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (108).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (11).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (11).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (110).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (110).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (111).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (111).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (112).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (112).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (113).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (113).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (115).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (115).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (116).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (116).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (117).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (117).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (118).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (118).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (119).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (119).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (12).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (12).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (120).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (120).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (121).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (121).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (123).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (123).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (124).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (124).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (125).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (125).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (126).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (126).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (128).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (128).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (129).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (129).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (13).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (13).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (130).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (130).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (131).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (131).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (133).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (133).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (134).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (134).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (137).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (137).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (138).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (138).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (139).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (139).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (14).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (14).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (140).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (140).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (142).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (142).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (143).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (143).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (144).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (144).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (146).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (146).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (147).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (147).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (148).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (148).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (149).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (149).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (150).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (150).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (151).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (151).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (152).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (152).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (153).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (153).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (154).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (154).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (155).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (155).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (156).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (156).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (157).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (157).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (158).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (158).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (159).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (159).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (16).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (16).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (160).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (160).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (161).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (161).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (162).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (162).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (163).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (163).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (164).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (164).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (167).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (167).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (168).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (168).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (17).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (17).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (170).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (170).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (171).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (171).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (172).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (172).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (173).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (173).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (175).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (175).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (177).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (177).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (178).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (178).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (18).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (18).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (181).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (181).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (182).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (182).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (183).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (183).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (184).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (184).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (185).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (185).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (186).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (186).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (187).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (187).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (188).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (188).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (189).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (189).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (19).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (19).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (190).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (190).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (193).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (193).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (194).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (194).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (195).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (195).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (196).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (196).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (197).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (197).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (198).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (198).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (199).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (199).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (20).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (20).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (200).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (200).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (201).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (201).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (204).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (204).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (205).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (205).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (206).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (206).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (208).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (208).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (209).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (209).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (21).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (21).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (210).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (210).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (211).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (211).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (212).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (212).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (213).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (213).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (214).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (214).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (215).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (215).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (216).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (216).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (217).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (217).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (218).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (218).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (219).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (219).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (22).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (22).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (220).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (220).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (221).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (221).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (222).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (222).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (223).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (223).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (224).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (224).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (225).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (225).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (226).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (226).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (227).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (227).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (228).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (228).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (229).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (229).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (23).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (23).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (230).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (230).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (231).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (231).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (232).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (232).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (233).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (233).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (234).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (234).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (235).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (235).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (237).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (237).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (239).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (239).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (24).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (24).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (240).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (240).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (241).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (241).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (242).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (242).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (243).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (243).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (244).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (244).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (245).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (245).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (246).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (246).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (247).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (247).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (248).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (248).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (25).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (25).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (251).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (251).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (253).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (253).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (254).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (254).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (255).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (255).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (256).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (256).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (257).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (257).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (258).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (258).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (259).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (259).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (26).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (26).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (260).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (260).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (262).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (262).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (264).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (264).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (265).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (265).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (266).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (266).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (267).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (267).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (268).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (268).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (269).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (269).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (27).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (27).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (270).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (270).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (271).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (271).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (272).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (272).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (273).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (273).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (274).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (274).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (275).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (275).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (276).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (276).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (277).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (277).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (278).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (278).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (279).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (279).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (28).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (28).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (280).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (280).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (281).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (281).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (283).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (283).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (284).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (284).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (285).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (285).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (286).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (286).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (287).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (287).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (288).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (288).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (289).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (289).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (29).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (29).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (290).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (290).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (291).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (291).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (292).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (292).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (293).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (293).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (294).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (294).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (296).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (296).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (298).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (298).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (299).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (299).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (3).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (3).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (30).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (30).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (300).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (300).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (302).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (302).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (303).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (303).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (304).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (304).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (305).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (305).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (306).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (306).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (307).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (307).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (308).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (308).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (309).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (309).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (31).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (31).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (310).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (310).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (311).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (311).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (312).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (312).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (314).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (314).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (315).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (315).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (317).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (317).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (318).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (318).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (319).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (319).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (32).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (32).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (320).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (320).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (321).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (321).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (323).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (323).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (324).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (324).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (325).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (325).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (326).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (326).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (328).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (328).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (329).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (329).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (330).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (330).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (333).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (333).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (334).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (334).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (335).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (335).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (336).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (336).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (337).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (337).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (338).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (338).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (34).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (34).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (341).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (341).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (342).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (342).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (344).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (344).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (346).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (346).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (347).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (347).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (348).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (348).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (349).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (349).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (35).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (35).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (350).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (350).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (36).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (36).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (37).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (37).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (38).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (38).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (39).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (39).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (40).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (40).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (41).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (41).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (42).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (42).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (43).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (43).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (45).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (45).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (46).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (46).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (48).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (48).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (49).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (49).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (50).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (50).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (51).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (51).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (52).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (52).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (54).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (54).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (56).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (56).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (57).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (57).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (63).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (63).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (64).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (64).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (65).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (65).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (66).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (66).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (67).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (67).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (68).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (68).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (69).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (69).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (7).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (7).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (70).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (70).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (72).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (72).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (73).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (73).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (74).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (74).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (75).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (75).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (76).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (76).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (78).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (78).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (79).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (79).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (8).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (8).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (82).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (82).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (84).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (84).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (85).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (85).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (87).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (87).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\acral melanoma\AM (88).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\AM (88).npy
# ...
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (328).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (328).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (329).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (329).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (33).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (33).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (331).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (331).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (333).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (333).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (336).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (336).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (337).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (337).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (338).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (338).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (34).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (34).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (341).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (341).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (342).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (342).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (343).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (343).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (346).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (346).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (348).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (348).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (349).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (349).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (350).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (350).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (351).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (351).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (355).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (355).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (357).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (357).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (358).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (358).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (36).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (36).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (360).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (360).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (361).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (361).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (362).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (362).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (363).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (363).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (364).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (364).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (365).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (365).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (366).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (366).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (367).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (367).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (369).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (369).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (37).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (37).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (370).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (370).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (371).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (371).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (373).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (373).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (374).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (374).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (38).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (38).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (39).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (39).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (4).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (4).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (40).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (40).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (41).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (41).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (42).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (42).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (44).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (44).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (45).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (45).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (46).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (46).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (47).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (47).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (48).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (48).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (49).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (49).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (5).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (5).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (50).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (50).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (51).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (51).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (52).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (52).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (53).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (53).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (54).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (54).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (55).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (55).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (56).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (56).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (57).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (57).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (58).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (58).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (59).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (59).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (6).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (6).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (61).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (61).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (62).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (62).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (63).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (63).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (64).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (64).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (65).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (65).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (66).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (66).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (67).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (67).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (69).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (69).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (7).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (7).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (70).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (70).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (71).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (71).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (72).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (72).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (74).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (74).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (76).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (76).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (79).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (79).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (80).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (80).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (81).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (81).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (82).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (82).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (84).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (84).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (85).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (85).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (86).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (86).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (87).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (87).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (88).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (88).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (89).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (89).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (9).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (9).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (90).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (90).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (91).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (91).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (93).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (93).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (95).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (95).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (96).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (96).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (97).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (97).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (98).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (98).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [80 20]\training\benign nevi\BN (99).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 2 - [80 20]\BN (99).npy
