# %% [markdown]
# ### Code untuk di Jupyter notebook

# %%
# %cd D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]
# Out:
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]

# %%
# %ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is BC6D-4CE5
#
#  Directory of D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]
#
# 13/12/2021  14:34    <DIR>          .
# 13/12/2021  14:34    <DIR>          ..
# 13/12/2021  14:33    <DIR>          testing
# 13/12/2021  14:33    <DIR>          training
#                0 File(s)              0 bytes
#                4 Dir(s)  962.147.569.664 bytes free

# %%
import os
# path di jupyter
base_dataset = 'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [70 30]/'

# %%
# inisialisasi direktori data train dan validasi beserta data per kategori
dir1 = [r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [70 30]/training/acral melanoma/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [70 30]/testing/acral melanoma/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [70 30]/training/benign nevi/',
        r'D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [70 30]/testing/benign nevi/']

# %% [markdown]
# # SVM Classifier

# %%
def preprocess(img,input_size):
    nimg = img.convert('RGB').resize(input_size)
    img_arr = (np.array(nimg))
    return img_arr

def reshape(imgs_arr):
    return np.stack(imgs_arr, axis=0)

# %%
# %matplotlib inline
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten, Dropout 
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from PIL import Image

import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
import os

# %%
def get_imlist(path):
    return [os.path.join(path,f) for f in os.listdir(path) if f.endswith('.jpg')]

# %%
from keras.models import Model
from keras.layers import Flatten, Dropout, Dense, Input, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, GlobalAveragePooling2D
from keras.layers.merge import concatenate

class FeatureExtractor:
    def __init__(self):
        inputs = Input(shape=(224,224,3))
      
        conv1 = Conv2D(32, kernel_size=3, strides = 1, activation='relu')(inputs)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
        
        conv1 = Conv2D(64, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(128, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(256, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        conv1 = Conv2D(512, kernel_size=3, strides = 1, activation='relu')(pool1)
        pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

        flat = Flatten()(pool1)
        drop_out1 = Dropout(0.5)(flat)

        self.model = Model(inputs=inputs, outputs=drop_out1)
        

    def extract_features(self, img_path):
        im = Image.open(img_path)
        X = preprocess(im,(224,224))
        X = reshape([X])
        
        feat = self.model.predict(X)
        norm_feat = feat[0]/LA.norm(feat[0])
        return norm_feat

# %%
model = FeatureExtractor()

# %%
feats = []
names = []
dir_training = [dir1[0], dir1[2]]

for direktori in dir_training:
    img_list = get_imlist(direktori)
    for i, img_path in enumerate(img_list):
        norm_feat = model.extract_features(img_path)
        img_name = os.path.split(img_path)[1]
        feats.append(norm_feat)
        if 'AM' in img_name:
            names.append('acral melanoma')
        else:
            names.append('benign nevi')
        print("extracting feature from image No. %d , %d images in total" %((i+1), len(img_list)))

feats = np.array(feats)
names = np.array(names)
# Out:
# extracting feature from image No. 1 , 232 images in total
# extracting feature from image No. 2 , 232 images in total
# extracting feature from image No. 3 , 232 images in total
# extracting feature from image No. 4 , 232 images in total
# extracting feature from image No. 5 , 232 images in total
# extracting feature from image No. 6 , 232 images in total
# extracting feature from image No. 7 , 232 images in total
# extracting feature from image No. 8 , 232 images in total
# extracting feature from image No. 9 , 232 images in total
# extracting feature from image No. 10 , 232 images in total
# extracting feature from image No. 11 , 232 images in total
# extracting feature from image No. 12 , 232 images in total
# extracting feature from image No. 13 , 232 images in total
# extracting feature from image No. 14 , 232 images in total
# extracting feature from image No. 15 , 232 images in total
# extracting feature from image No. 16 , 232 images in total
# extracting feature from image No. 17 , 232 images in total
# extracting feature from image No. 18 , 232 images in total
# extracting feature from image No. 19 , 232 images in total
# extracting feature from image No. 20 , 232 images in total
# extracting feature from image No. 21 , 232 images in total
# extracting feature from image No. 22 , 232 images in total
# extracting feature from image No. 23 , 232 images in total
# extracting feature from image No. 24 , 232 images in total
# extracting feature from image No. 25 , 232 images in total
# extracting feature from image No. 26 , 232 images in total
# extracting feature from image No. 27 , 232 images in total
# extracting feature from image No. 28 , 232 images in total
# extracting feature from image No. 29 , 232 images in total
# extracting feature from image No. 30 , 232 images in total
# extracting feature from image No. 31 , 232 images in total
# extracting feature from image No. 32 , 232 images in total
# extracting feature from image No. 33 , 232 images in total
# extracting feature from image No. 34 , 232 images in total
# extracting feature from image No. 35 , 232 images in total
# extracting feature from image No. 36 , 232 images in total
# extracting feature from image No. 37 , 232 images in total
# extracting feature from image No. 38 , 232 images in total
# extracting feature from image No. 39 , 232 images in total
# extracting feature from image No. 40 , 232 images in total
# extracting feature from image No. 41 , 232 images in total
# extracting feature from image No. 42 , 232 images in total
# extracting feature from image No. 43 , 232 images in total
# extracting feature from image No. 44 , 232 images in total
# extracting feature from image No. 45 , 232 images in total
# extracting feature from image No. 46 , 232 images in total
# extracting feature from image No. 47 , 232 images in total
# extracting feature from image No. 48 , 232 images in total
# extracting feature from image No. 49 , 232 images in total
# extracting feature from image No. 50 , 232 images in total
# extracting feature from image No. 51 , 232 images in total
# extracting feature from image No. 52 , 232 images in total
# extracting feature from image No. 53 , 232 images in total
# extracting feature from image No. 54 , 232 images in total
# extracting feature from image No. 55 , 232 images in total
# extracting feature from image No. 56 , 232 images in total
# extracting feature from image No. 57 , 232 images in total
# extracting feature from image No. 58 , 232 images in total
# extracting feature from image No. 59 , 232 images in total
# extracting feature from image No. 60 , 232 images in total
# extracting feature from image No. 61 , 232 images in total
# extracting feature from image No. 62 , 232 images in total
# extracting feature from image No. 63 , 232 images in total
# extracting feature from image No. 64 , 232 images in total
# extracting feature from image No. 65 , 232 images in total
# extracting feature from image No. 66 , 232 images in total
# extracting feature from image No. 67 , 232 images in total
# extracting feature from image No. 68 , 232 images in total
# extracting feature from image No. 69 , 232 images in total
# extracting feature from image No. 70 , 232 images in total
# extracting feature from image No. 71 , 232 images in total
# extracting feature from image No. 72 , 232 images in total
# extracting feature from image No. 73 , 232 images in total
# extracting feature from image No. 74 , 232 images in total
# extracting feature from image No. 75 , 232 images in total
# extracting feature from image No. 76 , 232 images in total
# extracting feature from image No. 77 , 232 images in total
# extracting feature from image No. 78 , 232 images in total
# extracting feature from image No. 79 , 232 images in total
# extracting feature from image No. 80 , 232 images in total
# extracting feature from image No. 81 , 232 images in total
# extracting feature from image No. 82 , 232 images in total
# extracting feature from image No. 83 , 232 images in total
# extracting feature from image No. 84 , 232 images in total
# extracting feature from image No. 85 , 232 images in total
# extracting feature from image No. 86 , 232 images in total
# extracting feature from image No. 87 , 232 images in total
# extracting feature from image No. 88 , 232 images in total
# extracting feature from image No. 89 , 232 images in total
# extracting feature from image No. 90 , 232 images in total
# extracting feature from image No. 91 , 232 images in total
# extracting feature from image No. 92 , 232 images in total
# extracting feature from image No. 93 , 232 images in total
# extracting feature from image No. 94 , 232 images in total
# extracting feature from image No. 95 , 232 images in total
# extracting feature from image No. 96 , 232 images in total
# extracting feature from image No. 97 , 232 images in total
# extracting feature from image No. 98 , 232 images in total
# extracting feature from image No. 99 , 232 images in total
# extracting feature from image No. 100 , 232 images in total
# extracting feature from image No. 101 , 232 images in total
# extracting feature from image No. 102 , 232 images in total
# extracting feature from image No. 103 , 232 images in total
# extracting feature from image No. 104 , 232 images in total
# extracting feature from image No. 105 , 232 images in total
# extracting feature from image No. 106 , 232 images in total
# extracting feature from image No. 107 , 232 images in total
# extracting feature from image No. 108 , 232 images in total
# extracting feature from image No. 109 , 232 images in total
# extracting feature from image No. 110 , 232 images in total
# extracting feature from image No. 111 , 232 images in total
# extracting feature from image No. 112 , 232 images in total
# extracting feature from image No. 113 , 232 images in total
# extracting feature from image No. 114 , 232 images in total
# extracting feature from image No. 115 , 232 images in total
# extracting feature from image No. 116 , 232 images in total
# extracting feature from image No. 117 , 232 images in total
# extracting feature from image No. 118 , 232 images in total
# extracting feature from image No. 119 , 232 images in total
# extracting feature from image No. 120 , 232 images in total
# extracting feature from image No. 121 , 232 images in total
# extracting feature from image No. 122 , 232 images in total
# extracting feature from image No. 123 , 232 images in total
# extracting feature from image No. 124 , 232 images in total
# extracting feature from image No. 125 , 232 images in total
# extracting feature from image No. 126 , 232 images in total
# extracting feature from image No. 127 , 232 images in total
# extracting feature from image No. 128 , 232 images in total
# extracting feature from image No. 129 , 232 images in total
# extracting feature from image No. 130 , 232 images in total
# extracting feature from image No. 131 , 232 images in total
# extracting feature from image No. 132 , 232 images in total
# extracting feature from image No. 133 , 232 images in total
# extracting feature from image No. 134 , 232 images in total
# extracting feature from image No. 135 , 232 images in total
# extracting feature from image No. 136 , 232 images in total
# extracting feature from image No. 137 , 232 images in total
# extracting feature from image No. 138 , 232 images in total
# extracting feature from image No. 139 , 232 images in total
# extracting feature from image No. 140 , 232 images in total
# extracting feature from image No. 141 , 232 images in total
# extracting feature from image No. 142 , 232 images in total
# extracting feature from image No. 143 , 232 images in total
# extracting feature from image No. 144 , 232 images in total
# extracting feature from image No. 145 , 232 images in total
# extracting feature from image No. 146 , 232 images in total
# extracting feature from image No. 147 , 232 images in total
# extracting feature from image No. 148 , 232 images in total
# extracting feature from image No. 149 , 232 images in total
# extracting feature from image No. 150 , 232 images in total
# extracting feature from image No. 151 , 232 images in total
# extracting feature from image No. 152 , 232 images in total
# extracting feature from image No. 153 , 232 images in total
# extracting feature from image No. 154 , 232 images in total
# extracting feature from image No. 155 , 232 images in total
# extracting feature from image No. 156 , 232 images in total
# extracting feature from image No. 157 , 232 images in total
# extracting feature from image No. 158 , 232 images in total
# extracting feature from image No. 159 , 232 images in total
# extracting feature from image No. 160 , 232 images in total
# extracting feature from image No. 161 , 232 images in total
# extracting feature from image No. 162 , 232 images in total
# extracting feature from image No. 163 , 232 images in total
# extracting feature from image No. 164 , 232 images in total
# extracting feature from image No. 165 , 232 images in total
# extracting feature from image No. 166 , 232 images in total
# extracting feature from image No. 167 , 232 images in total
# extracting feature from image No. 168 , 232 images in total
# extracting feature from image No. 169 , 232 images in total
# extracting feature from image No. 170 , 232 images in total
# extracting feature from image No. 171 , 232 images in total
# extracting feature from image No. 172 , 232 images in total
# extracting feature from image No. 173 , 232 images in total
# extracting feature from image No. 174 , 232 images in total
# extracting feature from image No. 175 , 232 images in total
# extracting feature from image No. 176 , 232 images in total
# extracting feature from image No. 177 , 232 images in total
# extracting feature from image No. 178 , 232 images in total
# extracting feature from image No. 179 , 232 images in total
# extracting feature from image No. 180 , 232 images in total
# extracting feature from image No. 181 , 232 images in total
# extracting feature from image No. 182 , 232 images in total
# extracting feature from image No. 183 , 232 images in total
# extracting feature from image No. 184 , 232 images in total
# extracting feature from image No. 185 , 232 images in total
# extracting feature from image No. 186 , 232 images in total
# extracting feature from image No. 187 , 232 images in total
# extracting feature from image No. 188 , 232 images in total
# extracting feature from image No. 189 , 232 images in total
# extracting feature from image No. 190 , 232 images in total
# extracting feature from image No. 191 , 232 images in total
# extracting feature from image No. 192 , 232 images in total
# extracting feature from image No. 193 , 232 images in total
# extracting feature from image No. 194 , 232 images in total
# extracting feature from image No. 195 , 232 images in total
# extracting feature from image No. 196 , 232 images in total
# extracting feature from image No. 197 , 232 images in total
# extracting feature from image No. 198 , 232 images in total
# extracting feature from image No. 199 , 232 images in total
# extracting feature from image No. 200 , 232 images in total
# extracting feature from image No. 201 , 232 images in total
# extracting feature from image No. 202 , 232 images in total
# extracting feature from image No. 203 , 232 images in total
# extracting feature from image No. 204 , 232 images in total
# extracting feature from image No. 205 , 232 images in total
# extracting feature from image No. 206 , 232 images in total
# extracting feature from image No. 207 , 232 images in total
# extracting feature from image No. 208 , 232 images in total
# extracting feature from image No. 209 , 232 images in total
# extracting feature from image No. 210 , 232 images in total
# extracting feature from image No. 211 , 232 images in total
# extracting feature from image No. 212 , 232 images in total
# extracting feature from image No. 213 , 232 images in total
# extracting feature from image No. 214 , 232 images in total
# extracting feature from image No. 215 , 232 images in total
# extracting feature from image No. 216 , 232 images in total
# extracting feature from image No. 217 , 232 images in total
# extracting feature from image No. 218 , 232 images in total
# extracting feature from image No. 219 , 232 images in total
# extracting feature from image No. 220 , 232 images in total
# extracting feature from image No. 221 , 232 images in total
# extracting feature from image No. 222 , 232 images in total
# extracting feature from image No. 223 , 232 images in total
# extracting feature from image No. 224 , 232 images in total
# extracting feature from image No. 225 , 232 images in total
# extracting feature from image No. 226 , 232 images in total
# extracting feature from image No. 227 , 232 images in total
# extracting feature from image No. 228 , 232 images in total
# extracting feature from image No. 229 , 232 images in total
# extracting feature from image No. 230 , 232 images in total
# extracting feature from image No. 231 , 232 images in total
# extracting feature from image No. 232 , 232 images in total
# extracting feature from image No. 1 , 187 images in total
# extracting feature from image No. 2 , 187 images in total
# extracting feature from image No. 3 , 187 images in total
# extracting feature from image No. 4 , 187 images in total
# extracting feature from image No. 5 , 187 images in total
# extracting feature from image No. 6 , 187 images in total
# extracting feature from image No. 7 , 187 images in total
# extracting feature from image No. 8 , 187 images in total
# extracting feature from image No. 9 , 187 images in total
# extracting feature from image No. 10 , 187 images in total
# extracting feature from image No. 11 , 187 images in total
# extracting feature from image No. 12 , 187 images in total
# extracting feature from image No. 13 , 187 images in total
# extracting feature from image No. 14 , 187 images in total
# extracting feature from image No. 15 , 187 images in total
# extracting feature from image No. 16 , 187 images in total
# extracting feature from image No. 17 , 187 images in total
# extracting feature from image No. 18 , 187 images in total
# extracting feature from image No. 19 , 187 images in total
# extracting feature from image No. 20 , 187 images in total
# extracting feature from image No. 21 , 187 images in total
# extracting feature from image No. 22 , 187 images in total
# extracting feature from image No. 23 , 187 images in total
# extracting feature from image No. 24 , 187 images in total
# extracting feature from image No. 25 , 187 images in total
# extracting feature from image No. 26 , 187 images in total
# extracting feature from image No. 27 , 187 images in total
# extracting feature from image No. 28 , 187 images in total
# extracting feature from image No. 29 , 187 images in total
# extracting feature from image No. 30 , 187 images in total
# extracting feature from image No. 31 , 187 images in total
# extracting feature from image No. 32 , 187 images in total
# extracting feature from image No. 33 , 187 images in total
# extracting feature from image No. 34 , 187 images in total
# extracting feature from image No. 35 , 187 images in total
# extracting feature from image No. 36 , 187 images in total
# extracting feature from image No. 37 , 187 images in total
# extracting feature from image No. 38 , 187 images in total
# extracting feature from image No. 39 , 187 images in total
# extracting feature from image No. 40 , 187 images in total
# extracting feature from image No. 41 , 187 images in total
# extracting feature from image No. 42 , 187 images in total
# extracting feature from image No. 43 , 187 images in total
# extracting feature from image No. 44 , 187 images in total
# extracting feature from image No. 45 , 187 images in total
# extracting feature from image No. 46 , 187 images in total
# extracting feature from image No. 47 , 187 images in total
# extracting feature from image No. 48 , 187 images in total
# extracting feature from image No. 49 , 187 images in total
# extracting feature from image No. 50 , 187 images in total
# extracting feature from image No. 51 , 187 images in total
# extracting feature from image No. 52 , 187 images in total
# extracting feature from image No. 53 , 187 images in total
# extracting feature from image No. 54 , 187 images in total
# extracting feature from image No. 55 , 187 images in total
# extracting feature from image No. 56 , 187 images in total
# extracting feature from image No. 57 , 187 images in total
# extracting feature from image No. 58 , 187 images in total
# extracting feature from image No. 59 , 187 images in total
# extracting feature from image No. 60 , 187 images in total
# extracting feature from image No. 61 , 187 images in total
# extracting feature from image No. 62 , 187 images in total
# extracting feature from image No. 63 , 187 images in total
# extracting feature from image No. 64 , 187 images in total
# extracting feature from image No. 65 , 187 images in total
# extracting feature from image No. 66 , 187 images in total
# extracting feature from image No. 67 , 187 images in total
# extracting feature from image No. 68 , 187 images in total
# extracting feature from image No. 69 , 187 images in total
# extracting feature from image No. 70 , 187 images in total
# extracting feature from image No. 71 , 187 images in total
# extracting feature from image No. 72 , 187 images in total
# extracting feature from image No. 73 , 187 images in total
# extracting feature from image No. 74 , 187 images in total
# extracting feature from image No. 75 , 187 images in total
# extracting feature from image No. 76 , 187 images in total
# extracting feature from image No. 77 , 187 images in total
# extracting feature from image No. 78 , 187 images in total
# extracting feature from image No. 79 , 187 images in total
# extracting feature from image No. 80 , 187 images in total
# extracting feature from image No. 81 , 187 images in total
# extracting feature from image No. 82 , 187 images in total
# extracting feature from image No. 83 , 187 images in total
# extracting feature from image No. 84 , 187 images in total
# extracting feature from image No. 85 , 187 images in total
# extracting feature from image No. 86 , 187 images in total
# extracting feature from image No. 87 , 187 images in total
# extracting feature from image No. 88 , 187 images in total
# extracting feature from image No. 89 , 187 images in total
# extracting feature from image No. 90 , 187 images in total
# extracting feature from image No. 91 , 187 images in total
# extracting feature from image No. 92 , 187 images in total
# extracting feature from image No. 93 , 187 images in total
# extracting feature from image No. 94 , 187 images in total
# extracting feature from image No. 95 , 187 images in total
# extracting feature from image No. 96 , 187 images in total
# extracting feature from image No. 97 , 187 images in total
# extracting feature from image No. 98 , 187 images in total
# extracting feature from image No. 99 , 187 images in total
# extracting feature from image No. 100 , 187 images in total
# extracting feature from image No. 101 , 187 images in total
# extracting feature from image No. 102 , 187 images in total
# extracting feature from image No. 103 , 187 images in total
# extracting feature from image No. 104 , 187 images in total
# extracting feature from image No. 105 , 187 images in total
# extracting feature from image No. 106 , 187 images in total
# extracting feature from image No. 107 , 187 images in total
# extracting feature from image No. 108 , 187 images in total
# extracting feature from image No. 109 , 187 images in total
# extracting feature from image No. 110 , 187 images in total
# extracting feature from image No. 111 , 187 images in total
# extracting feature from image No. 112 , 187 images in total
# extracting feature from image No. 113 , 187 images in total
# extracting feature from image No. 114 , 187 images in total
# extracting feature from image No. 115 , 187 images in total
# extracting feature from image No. 116 , 187 images in total
# extracting feature from image No. 117 , 187 images in total
# extracting feature from image No. 118 , 187 images in total
# extracting feature from image No. 119 , 187 images in total
# extracting feature from image No. 120 , 187 images in total
# extracting feature from image No. 121 , 187 images in total
# extracting feature from image No. 122 , 187 images in total
# extracting feature from image No. 123 , 187 images in total
# extracting feature from image No. 124 , 187 images in total
# extracting feature from image No. 125 , 187 images in total
# extracting feature from image No. 126 , 187 images in total
# extracting feature from image No. 127 , 187 images in total
# extracting feature from image No. 128 , 187 images in total
# extracting feature from image No. 129 , 187 images in total
# extracting feature from image No. 130 , 187 images in total
# extracting feature from image No. 131 , 187 images in total
# extracting feature from image No. 132 , 187 images in total
# extracting feature from image No. 133 , 187 images in total
# extracting feature from image No. 134 , 187 images in total
# extracting feature from image No. 135 , 187 images in total
# extracting feature from image No. 136 , 187 images in total
# extracting feature from image No. 137 , 187 images in total
# extracting feature from image No. 138 , 187 images in total
# extracting feature from image No. 139 , 187 images in total
# extracting feature from image No. 140 , 187 images in total
# extracting feature from image No. 141 , 187 images in total
# extracting feature from image No. 142 , 187 images in total
# extracting feature from image No. 143 , 187 images in total
# extracting feature from image No. 144 , 187 images in total
# extracting feature from image No. 145 , 187 images in total
# extracting feature from image No. 146 , 187 images in total
# extracting feature from image No. 147 , 187 images in total
# extracting feature from image No. 148 , 187 images in total
# extracting feature from image No. 149 , 187 images in total
# extracting feature from image No. 150 , 187 images in total
# extracting feature from image No. 151 , 187 images in total
# extracting feature from image No. 152 , 187 images in total
# extracting feature from image No. 153 , 187 images in total
# extracting feature from image No. 154 , 187 images in total
# extracting feature from image No. 155 , 187 images in total
# extracting feature from image No. 156 , 187 images in total
# extracting feature from image No. 157 , 187 images in total
# extracting feature from image No. 158 , 187 images in total
# extracting feature from image No. 159 , 187 images in total
# extracting feature from image No. 160 , 187 images in total
# extracting feature from image No. 161 , 187 images in total
# extracting feature from image No. 162 , 187 images in total
# extracting feature from image No. 163 , 187 images in total
# extracting feature from image No. 164 , 187 images in total
# extracting feature from image No. 165 , 187 images in total
# extracting feature from image No. 166 , 187 images in total
# extracting feature from image No. 167 , 187 images in total
# extracting feature from image No. 168 , 187 images in total
# extracting feature from image No. 169 , 187 images in total
# extracting feature from image No. 170 , 187 images in total
# extracting feature from image No. 171 , 187 images in total
# extracting feature from image No. 172 , 187 images in total
# extracting feature from image No. 173 , 187 images in total
# extracting feature from image No. 174 , 187 images in total
# extracting feature from image No. 175 , 187 images in total
# extracting feature from image No. 176 , 187 images in total
# extracting feature from image No. 177 , 187 images in total
# extracting feature from image No. 178 , 187 images in total
# extracting feature from image No. 179 , 187 images in total
# extracting feature from image No. 180 , 187 images in total
# extracting feature from image No. 181 , 187 images in total
# extracting feature from image No. 182 , 187 images in total
# extracting feature from image No. 183 , 187 images in total
# extracting feature from image No. 184 , 187 images in total
# extracting feature from image No. 185 , 187 images in total
# extracting feature from image No. 186 , 187 images in total
# extracting feature from image No. 187 , 187 images in total

# %%
feats_test = []
names_test = []
dir_test = [dir1[1], dir1[3]]
for direktori in dir_test:
    img_list = get_imlist(direktori)
    for i, img_path in enumerate(img_list):
        norm_feat = model.extract_features(img_path)
        img_name = os.path.split(img_path)[1]
        feats_test.append(norm_feat)
        if 'AM' in img_name:
            names_test.append('acral melanoma')
        else:
            names_test.append('benign nevi')
        print("extracting feature from image No. %d , %d images in total" %((i+1), len(img_list)))

feats_test = np.array(feats_test)
names_test = np.array(names_test)
# Out:
# extracting feature from image No. 1 , 98 images in total
# extracting feature from image No. 2 , 98 images in total
# extracting feature from image No. 3 , 98 images in total
# extracting feature from image No. 4 , 98 images in total
# extracting feature from image No. 5 , 98 images in total
# extracting feature from image No. 6 , 98 images in total
# extracting feature from image No. 7 , 98 images in total
# extracting feature from image No. 8 , 98 images in total
# extracting feature from image No. 9 , 98 images in total
# extracting feature from image No. 10 , 98 images in total
# extracting feature from image No. 11 , 98 images in total
# extracting feature from image No. 12 , 98 images in total
# extracting feature from image No. 13 , 98 images in total
# extracting feature from image No. 14 , 98 images in total
# extracting feature from image No. 15 , 98 images in total
# extracting feature from image No. 16 , 98 images in total
# extracting feature from image No. 17 , 98 images in total
# extracting feature from image No. 18 , 98 images in total
# extracting feature from image No. 19 , 98 images in total
# extracting feature from image No. 20 , 98 images in total
# extracting feature from image No. 21 , 98 images in total
# extracting feature from image No. 22 , 98 images in total
# extracting feature from image No. 23 , 98 images in total
# extracting feature from image No. 24 , 98 images in total
# extracting feature from image No. 25 , 98 images in total
# extracting feature from image No. 26 , 98 images in total
# extracting feature from image No. 27 , 98 images in total
# extracting feature from image No. 28 , 98 images in total
# extracting feature from image No. 29 , 98 images in total
# extracting feature from image No. 30 , 98 images in total
# extracting feature from image No. 31 , 98 images in total
# extracting feature from image No. 32 , 98 images in total
# extracting feature from image No. 33 , 98 images in total
# extracting feature from image No. 34 , 98 images in total
# extracting feature from image No. 35 , 98 images in total
# extracting feature from image No. 36 , 98 images in total
# extracting feature from image No. 37 , 98 images in total
# extracting feature from image No. 38 , 98 images in total
# extracting feature from image No. 39 , 98 images in total
# extracting feature from image No. 40 , 98 images in total
# extracting feature from image No. 41 , 98 images in total
# extracting feature from image No. 42 , 98 images in total
# extracting feature from image No. 43 , 98 images in total
# extracting feature from image No. 44 , 98 images in total
# extracting feature from image No. 45 , 98 images in total
# extracting feature from image No. 46 , 98 images in total
# extracting feature from image No. 47 , 98 images in total
# extracting feature from image No. 48 , 98 images in total
# extracting feature from image No. 49 , 98 images in total
# extracting feature from image No. 50 , 98 images in total
# extracting feature from image No. 51 , 98 images in total
# extracting feature from image No. 52 , 98 images in total
# extracting feature from image No. 53 , 98 images in total
# extracting feature from image No. 54 , 98 images in total
# extracting feature from image No. 55 , 98 images in total
# extracting feature from image No. 56 , 98 images in total
# extracting feature from image No. 57 , 98 images in total
# extracting feature from image No. 58 , 98 images in total
# extracting feature from image No. 59 , 98 images in total
# extracting feature from image No. 60 , 98 images in total
# extracting feature from image No. 61 , 98 images in total
# extracting feature from image No. 62 , 98 images in total
# extracting feature from image No. 63 , 98 images in total
# extracting feature from image No. 64 , 98 images in total
# extracting feature from image No. 65 , 98 images in total
# extracting feature from image No. 66 , 98 images in total
# extracting feature from image No. 67 , 98 images in total
# extracting feature from image No. 68 , 98 images in total
# extracting feature from image No. 69 , 98 images in total
# extracting feature from image No. 70 , 98 images in total
# extracting feature from image No. 71 , 98 images in total
# extracting feature from image No. 72 , 98 images in total
# extracting feature from image No. 73 , 98 images in total
# extracting feature from image No. 74 , 98 images in total
# extracting feature from image No. 75 , 98 images in total
# extracting feature from image No. 76 , 98 images in total
# extracting feature from image No. 77 , 98 images in total
# extracting feature from image No. 78 , 98 images in total
# extracting feature from image No. 79 , 98 images in total
# extracting feature from image No. 80 , 98 images in total
# extracting feature from image No. 81 , 98 images in total
# extracting feature from image No. 82 , 98 images in total
# extracting feature from image No. 83 , 98 images in total
# extracting feature from image No. 84 , 98 images in total
# extracting feature from image No. 85 , 98 images in total
# extracting feature from image No. 86 , 98 images in total
# extracting feature from image No. 87 , 98 images in total
# extracting feature from image No. 88 , 98 images in total
# extracting feature from image No. 89 , 98 images in total
# extracting feature from image No. 90 , 98 images in total
# extracting feature from image No. 91 , 98 images in total
# extracting feature from image No. 92 , 98 images in total
# extracting feature from image No. 93 , 98 images in total
# extracting feature from image No. 94 , 98 images in total
# extracting feature from image No. 95 , 98 images in total
# extracting feature from image No. 96 , 98 images in total
# extracting feature from image No. 97 , 98 images in total
# extracting feature from image No. 98 , 98 images in total
# extracting feature from image No. 1 , 83 images in total
# extracting feature from image No. 2 , 83 images in total
# extracting feature from image No. 3 , 83 images in total
# extracting feature from image No. 4 , 83 images in total
# extracting feature from image No. 5 , 83 images in total
# extracting feature from image No. 6 , 83 images in total
# extracting feature from image No. 7 , 83 images in total
# extracting feature from image No. 8 , 83 images in total
# extracting feature from image No. 9 , 83 images in total
# extracting feature from image No. 10 , 83 images in total
# extracting feature from image No. 11 , 83 images in total
# extracting feature from image No. 12 , 83 images in total
# extracting feature from image No. 13 , 83 images in total
# extracting feature from image No. 14 , 83 images in total
# extracting feature from image No. 15 , 83 images in total
# extracting feature from image No. 16 , 83 images in total
# extracting feature from image No. 17 , 83 images in total
# extracting feature from image No. 18 , 83 images in total
# extracting feature from image No. 19 , 83 images in total
# extracting feature from image No. 20 , 83 images in total
# extracting feature from image No. 21 , 83 images in total
# extracting feature from image No. 22 , 83 images in total
# extracting feature from image No. 23 , 83 images in total
# extracting feature from image No. 24 , 83 images in total
# extracting feature from image No. 25 , 83 images in total
# extracting feature from image No. 26 , 83 images in total
# extracting feature from image No. 27 , 83 images in total
# extracting feature from image No. 28 , 83 images in total
# extracting feature from image No. 29 , 83 images in total
# extracting feature from image No. 30 , 83 images in total
# extracting feature from image No. 31 , 83 images in total
# extracting feature from image No. 32 , 83 images in total
# extracting feature from image No. 33 , 83 images in total
# extracting feature from image No. 34 , 83 images in total
# extracting feature from image No. 35 , 83 images in total
# extracting feature from image No. 36 , 83 images in total
# extracting feature from image No. 37 , 83 images in total
# extracting feature from image No. 38 , 83 images in total
# extracting feature from image No. 39 , 83 images in total
# extracting feature from image No. 40 , 83 images in total
# extracting feature from image No. 41 , 83 images in total
# extracting feature from image No. 42 , 83 images in total
# extracting feature from image No. 43 , 83 images in total
# extracting feature from image No. 44 , 83 images in total
# extracting feature from image No. 45 , 83 images in total
# extracting feature from image No. 46 , 83 images in total
# extracting feature from image No. 47 , 83 images in total
# extracting feature from image No. 48 , 83 images in total
# extracting feature from image No. 49 , 83 images in total
# extracting feature from image No. 50 , 83 images in total
# extracting feature from image No. 51 , 83 images in total
# extracting feature from image No. 52 , 83 images in total
# extracting feature from image No. 53 , 83 images in total
# extracting feature from image No. 54 , 83 images in total
# extracting feature from image No. 55 , 83 images in total
# extracting feature from image No. 56 , 83 images in total
# extracting feature from image No. 57 , 83 images in total
# extracting feature from image No. 58 , 83 images in total
# extracting feature from image No. 59 , 83 images in total
# extracting feature from image No. 60 , 83 images in total
# extracting feature from image No. 61 , 83 images in total
# extracting feature from image No. 62 , 83 images in total
# extracting feature from image No. 63 , 83 images in total
# extracting feature from image No. 64 , 83 images in total
# extracting feature from image No. 65 , 83 images in total
# extracting feature from image No. 66 , 83 images in total
# extracting feature from image No. 67 , 83 images in total
# extracting feature from image No. 68 , 83 images in total
# extracting feature from image No. 69 , 83 images in total
# extracting feature from image No. 70 , 83 images in total
# extracting feature from image No. 71 , 83 images in total
# extracting feature from image No. 72 , 83 images in total
# extracting feature from image No. 73 , 83 images in total
# extracting feature from image No. 74 , 83 images in total
# extracting feature from image No. 75 , 83 images in total
# extracting feature from image No. 76 , 83 images in total
# extracting feature from image No. 77 , 83 images in total
# extracting feature from image No. 78 , 83 images in total
# extracting feature from image No. 79 , 83 images in total
# extracting feature from image No. 80 , 83 images in total
# extracting feature from image No. 81 , 83 images in total
# extracting feature from image No. 82 , 83 images in total
# extracting feature from image No. 83 , 83 images in total

# %%
from sklearn.preprocessing import LabelEncoder
x_train = feats
x_test= feats_test

lb = LabelEncoder()
y_train = lb.fit_transform(names)
y_test = lb.fit_transform(names_test)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':['linear', 'poly', 'rbf', 'sigmoid'], 
              'C':[0.1,1, 10, 100],
              'gamma':[1e-1,1e-2,1e-3, 1e-4]}
clf = GridSearchCV(SVC(), parameters)
clf.fit(x_train, y_train)

svmclf = clf.best_estimator_
#svmclf = SVC(C=100, gamma=0.1, kernel='linear', probability = True)
modelsvm = svmclf.fit(x_train, y_train)

# %%
svmclf
# Out:
# SVC(C=100, gamma=0.1, kernel='linear')

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
y_testSVM = modelsvm.predict(x_test)

labels = (y_testSVM > 0.5).astype(int)
target_names = ['acral melanoma', 'benign nevi']
print(classification_report(y_test, labels, target_names=target_names))

print('Confusion Matrix')
print(confusion_matrix(y_test, labels))
print('acc score : ', modelsvm.score(x_test,y_test))
# Out:
#                 precision    recall  f1-score   support
#
# acral melanoma       0.92      0.85      0.88        98
#    benign nevi       0.84      0.92      0.87        83
#
#       accuracy                           0.88       181
#      macro avg       0.88      0.88      0.88       181
#   weighted avg       0.88      0.88      0.88       181
#
# Confusion Matrix
# [[83 15]
#  [ 7 76]]
# acc score :  0.8784530386740331

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(modelsvm, x_test, y_test)  
plt.savefig('D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 3 - [70 30]/cm-skenario-3.svg')
plt.show()
# Out:
# C:\Users\Fadhlan\Anaconda3\envs\tf2.6\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
import h5py
h5f = h5py.File('D:/SEMESTER 7/Pembelajaran Mesin/Dataset/process image-3 [90 10]/model/model-skenario-3.h5', 'w')
h5f.create_dataset('train_features', data=x_train)
h5f.create_dataset('train_labels', data=y_train)
h5f.create_dataset('test_features', data=x_test)
h5f.create_dataset('test_labels', data=y_test)
h5f.close()

# %%
svmclf.get_params()
# Out:
# {'C': 100,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 0.1,
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
nrows = 4
ncols = 5
input_size = (224, 224)
pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 5, nrows * 5)

pic_index += 20
melanoma_pix = [os.path.join(dir1[1], fname) for fname in os.listdir(dir1[1])[:10]]
benign_pix = [os.path.join(dir1[3], fname) for fname in os.listdir(dir1[3])[:10]]

for i, img_path in enumerate(melanoma_pix+benign_pix):
  # Set up subplot; subplot indices start at 1
    sp = plt.subplot(nrows, ncols, i+1)
    categories = ['acral melanoma', 'benign nevi']
    im = Image.open(img_path)
    norm_feat = model.extract_features(img_path)
    norm_feat = np.array(norm_feat)
    norm_feat = norm_feat.reshape(1, len(norm_feat))
    start = time.time()
    y = svmclf.predict(norm_feat)
    waktu = time.time() - start

    if categories[int(np.round(y, 0))] == 'benign nevi':
        plt.title(categories[int(np.round(y, 0))] + ' pred: '+ str(int(np.round(y, 0))))
        plt.xlabel(' waktu: ' + str(waktu))
    else:
        plt.title(categories[int(np.round(y, 0))] + ' pred: '+ str(int(np.round(y, 0))))
        plt.xlabel(' waktu: ' + str(waktu))
    #sp.axis('Off') # Don't show axes (or gridlines)

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
from sklearn.metrics import  precision_recall_curve, auc, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
fpr, tpr, _ = roc_curve(y_test, labels)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='#ffba93',
         lw=lw, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='#7579e7', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Skenario 3')
plt.legend(loc="lower right")
plt.savefig('D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 3 - [70 30]/roc-curve-skenario-3.svg')
plt.show()

# %%
from pathlib import Path

input_path = [dir1[0], dir1[2]]
output_path = 'D:/SEMESTER 7/Pembelajaran Mesin/features/Skenario 3 - [70 30]' 

for path in input_path: 
    for img_path in sorted(Path(path).glob('*.jpg')):
        print(img_path)

        feature = model.extract_features(img_path)

        feature_path = Path(output_path) / (img_path.stem + ".npy")
        print(feature_path)

        np.save(feature_path, feature)
# Out:
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (1).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (1).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (101).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (101).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (102).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (102).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (103).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (103).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (106).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (106).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (108).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (108).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (11).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (11).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (110).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (110).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (112).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (112).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (116).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (116).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (118).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (118).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (119).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (119).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (120).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (120).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (121).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (121).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (123).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (123).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (124).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (124).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (125).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (125).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (126).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (126).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (128).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (128).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (129).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (129).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (13).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (13).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (130).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (130).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (131).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (131).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (133).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (133).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (134).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (134).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (137).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (137).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (138).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (138).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (139).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (139).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (14).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (14).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (140).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (140).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (142).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (142).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (144).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (144).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (146).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (146).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (147).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (147).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (148).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (148).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (149).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (149).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (150).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (150).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (152).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (152).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (153).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (153).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (154).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (154).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (155).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (155).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (156).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (156).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (157).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (157).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (158).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (158).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (159).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (159).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (16).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (16).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (160).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (160).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (161).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (161).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (162).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (162).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (163).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (163).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (164).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (164).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (167).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (167).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (168).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (168).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (17).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (17).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (171).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (171).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (172).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (172).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (173).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (173).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (175).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (175).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (178).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (178).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (18).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (18).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (181).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (181).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (182).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (182).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (183).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (183).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (184).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (184).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (185).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (185).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (186).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (186).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (187).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (187).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (188).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (188).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (189).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (189).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (19).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (19).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (190).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (190).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (193).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (193).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (194).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (194).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (195).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (195).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (196).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (196).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (197).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (197).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (198).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (198).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (199).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (199).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (20).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (20).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (200).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (200).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (201).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (201).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (204).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (204).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (205).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (205).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (206).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (206).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (208).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (208).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (209).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (209).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (21).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (21).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (210).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (210).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (211).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (211).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (212).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (212).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (213).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (213).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (214).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (214).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (217).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (217).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (218).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (218).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (22).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (22).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (220).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (220).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (221).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (221).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (222).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (222).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (223).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (223).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (224).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (224).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (225).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (225).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (226).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (226).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (227).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (227).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (228).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (228).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (229).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (229).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (23).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (23).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (231).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (231).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (232).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (232).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (233).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (233).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (234).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (234).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (235).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (235).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (237).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (237).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (24).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (24).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (240).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (240).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (241).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (241).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (242).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (242).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (243).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (243).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (244).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (244).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (245).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (245).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (246).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (246).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (247).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (247).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (248).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (248).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (25).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (25).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (251).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (251).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (254).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (254).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (255).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (255).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (256).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (256).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (257).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (257).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (259).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (259).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (260).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (260).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (262).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (262).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (264).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (264).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (265).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (265).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (266).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (266).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (267).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (267).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (27).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (27).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (270).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (270).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (271).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (271).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (272).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (272).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (273).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (273).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (274).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (274).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (275).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (275).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (276).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (276).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (277).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (277).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (278).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (278).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (279).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (279).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (28).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (28).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (280).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (280).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (283).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (283).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (284).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (284).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (285).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (285).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (287).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (287).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (288).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (288).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (289).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (289).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (29).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (29).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (290).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (290).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (291).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (291).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (292).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (292).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (293).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (293).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (294).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (294).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (296).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (296).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (298).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (298).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (299).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (299).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (3).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (3).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (30).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (30).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (300).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (300).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (302).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (302).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (303).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (303).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (304).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (304).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (305).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (305).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (306).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (306).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (307).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (307).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (309).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (309).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (31).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (31).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (311).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (311).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (312).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (312).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (314).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (314).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (317).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (317).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (318).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (318).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (319).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (319).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (32).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (32).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (320).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (320).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (321).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (321).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (323).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (323).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (324).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (324).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (326).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (326).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (328).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (328).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (329).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (329).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (333).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (333).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (335).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (335).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (336).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (336).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (337).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (337).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (338).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (338).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (34).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (34).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (341).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (341).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (346).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (346).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (347).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (347).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (348).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (348).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (349).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (349).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (35).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (35).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (350).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (350).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (36).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (36).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (37).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (37).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (38).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (38).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (39).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (39).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (41).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (41).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (42).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (42).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (45).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (45).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (48).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (48).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (49).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (49).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (50).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (50).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (51).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (51).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (52).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (52).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (54).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (54).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (56).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (56).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (57).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (57).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (63).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (63).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (64).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (64).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (65).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (65).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (66).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (66).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (67).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (67).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (68).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (68).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (69).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (69).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (7).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (7).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (70).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (70).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (72).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (72).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (73).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (73).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (74).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (74).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (75).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (75).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (76).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (76).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (78).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (78).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (79).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (79).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (8).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (8).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (82).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (82).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (84).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (84).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (85).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (85).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (87).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (87).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (88).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (88).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (9).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (9).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (91).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (91).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (93).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (93).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (95).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (95).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (96).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (96).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (97).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (97).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\acral melanoma\AM (99).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\AM (99).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (10).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (10).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (100).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (100).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (101).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (101).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (102).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (102).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (103).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (103).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (104).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (104).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (106).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (106).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (107).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (107).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (108).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (108).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (11).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (11).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (112).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (112).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (113).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (113).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (115).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (115).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (116).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (116).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (117).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (117).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (12).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (12).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (120).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (120).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (121).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (121).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (122).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (122).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (123).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (123).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (124).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (124).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (126).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (126).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (127).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (127).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (128).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (128).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (129).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (129).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (132).JPG
# ...
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (307).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (307).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (308).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (308).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (309).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (309).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (31).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (31).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (310).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (310).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (312).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (312).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (315).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (315).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (316).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (316).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (317).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (317).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (318).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (318).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (321).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (321).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (322).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (322).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (323).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (323).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (328).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (328).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (329).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (329).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (33).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (33).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (331).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (331).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (333).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (333).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (336).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (336).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (337).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (337).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (338).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (338).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (34).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (34).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (342).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (342).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (343).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (343).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (346).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (346).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (348).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (348).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (349).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (349).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (350).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (350).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (357).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (357).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (358).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (358).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (36).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (36).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (360).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (360).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (362).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (362).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (364).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (364).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (365).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (365).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (366).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (366).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (367).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (367).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (369).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (369).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (37).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (37).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (370).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (370).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (371).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (371).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (373).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (373).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (374).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (374).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (38).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (38).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (39).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (39).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (4).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (4).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (40).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (40).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (41).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (41).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (45).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (45).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (46).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (46).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (47).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (47).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (48).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (48).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (49).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (49).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (5).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (5).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (50).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (50).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (51).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (51).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (52).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (52).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (53).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (53).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (55).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (55).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (56).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (56).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (57).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (57).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (58).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (58).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (59).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (59).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (6).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (6).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (61).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (61).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (62).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (62).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (63).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (63).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (64).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (64).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (65).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (65).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (67).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (67).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (7).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (7).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (70).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (70).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (71).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (71).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (72).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (72).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (74).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (74).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (76).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (76).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (79).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (79).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (80).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (80).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (81).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (81).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (82).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (82).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (84).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (84).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (85).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (85).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (86).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (86).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (87).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (87).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (88).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (88).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (9).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (9).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (91).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (91).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (93).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (93).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (95).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (95).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (97).JPG
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (97).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (98).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (98).npy
# D:\SEMESTER 7\Pembelajaran Mesin\Dataset\process image-3 [70 30]\training\benign nevi\BN (99).jpg
# D:\SEMESTER 7\Pembelajaran Mesin\features\Skenario 3 - [70 30]\BN (99).npy
